# %%
# 1)Write Python code that prints your name, student number and email address. 
name = 'Hanna Jabbar'
student_number = 9080706040
email = 'hannajabar@gmail.com'
print('Name:',name)
print('Student number is :',student_number)
print('Email is :',email)
# Out:
# Name: Hanna Jabbar
# Student number is : 9080706040
# Email is : hannajabar@gmail.com

# %%
# 2)Write Python code that prints your name, student number and email address using escape sequences.     
print('Name:\tHanna Jabbar')
print('Student Number:\t9080706040')
print('Email:\thannajabar@gmail.com')
# Out:
# Name:	Hanna Jabbar
# Student Number:	9080706040
# Email:	hannajabar@gmail.com

# %%
# 3)Write Python code that add, subtract, multiply and divide the two numbers. You can use the two numbers 14 and 7.
A = 14
B = 7
print('Addition:',A+B)
print('Subtraction:',A-B)
print('Subtraction:',A*B)
print('Subtraction:',A/B)
# Out:
# Addition: 21
# Subtraction: 7
# Subtraction: 98
# Subtraction: 2.0

# %%
# 4) Write Python code that displays the numbers from 1 to 5 as steps. 
for i in range(1,6):
    print('Step :',i)
# Out:
# Step : 1
# Step : 2
# Step : 3
# Step : 4
# Step : 5

# %%
# 5)Write Python code that outputs the following sentence (including the quotation marks and line break) to the screen: 
#"SDK" stands for "Software Development Kit", whereas 
#"IDE" stands for "Integrated Development Environment". 
print("\"SDK\" stands for \"Software Development Kit\", whereas \n\"IDE\" stands for \"Integrated Development Environment\".")
# Out:
# "SDK" stands for "Software Development Kit", whereas
# "IDE" stands for "Integrated Development Environment".

# %%
# 6) Practice and check the output
# 1)print("python is an \"awesome\" language.")
print("Python is an \"Awesome\" language.")
# Out:
# Python is an "Awesome" language.

# %%
# 2)print("python\n\t2023")
print("python\n\t2023")
# Out:
# python
# 	2023

# %%
# 3)print('I\'m from Entri.\b')
print('I\'m from Entri.\b')
# Out:
# I'm from Entri

# %%
# 4)print("\65")
print("\65")
# Out:
# 5

# %%
# 5)print("\x65")
print("\x65")
# Out:
# e

# %%
# 6)print("Entri", "2023", sep="\n")
print("Entri","2023",sep="\n")
# Out:
# Entri
# 2023

# %%
# 7) print("Entri", "2023", sep="\b")
print("Entri","2023",sep="\b")
# Out:
# Entr2023

# %%
# 8)print("Entri", "2023", sep="*", end="\b\b\b\b")
print("Entri", "2023", sep="*", end="\b\b\b\b")
# Out:
# Entri*20

# %%
# 7)Define the variables below. Print the types of each variable. What is the sum of your variables? 
#(Hint: use a type conversion function.) 
#What datatype is the sum?
#num=23
#textnum="57"
#decimal=98.3
num = 23
textnum= "57"
decimal= 98.3
print("Type of num is :",type(num))
print( 'Type of textnum is:',type(textnum))
print('Type of decimal is:',type(decimal))
sum_of_variables = num+int(textnum)+decimal
print('Sum of variables is:', sum_of_variables)
print('Type  of Sum is :',type(sum_of_variables))
# Out:
# Type of num is : <class 'int'>
# Type of textnum is: <class 'str'>
# Type of decimal is: <class 'float'>
# Sum of variables is: 178.3
# Type  of Sum is : <class 'float'>

# %%
# 8)calculate the number of minutes in a year using variables for each unit of time. print a statement that describes what your code does also.
#Create three variables to store no of days in a year, minute in a hour, hours in a day, then calculate the total minutes in a year and print the values
#(hint) total number of minutes in an year =No.of days in an year * Hours in a day * Minutes in an hour
# Define variables
No_of_days = 365
Hours_in_Day = 24
Minutes_in_hour = 60
Total_Minutes_in_Year = No_of_days * Hours_in_Day*Minutes_in_hour
print('This program calculates the total number of minutes in a year')
print('Total Minutes in a year is :',Total_Minutes_in_Year)
# Out:
# This program calculates the total number of minutes in a year
# Total Minutes in a year is : 525600

# %%
# 9)Write Python code that asks the user to enter his/her name and then output/prints his/her name with a greeting.
# ask for the user input
name =input("Please enter your Name:")
#greeting message 
print("Hi",name + ", Welcome to python programming")
# Out:
# Please enter your Name: Hadikha Thaskeen
# Hi Hadikha Thaskeen, Welcome to python programming

# %%
# 10)Exercise 10
#Name your file: PoundsToDollars.py
#Write a program that asks the user to enter an amount in pounds (£) and the program calculates and converts an amount in dollar ($)
#An example runs of the program:
#Please enter amount in pounds: XXX
#£ XXX are $ XXX
amount =float(input("Please enter an amount in pounds:£"))
conversion_rate = 1.27
dollars = amount*conversion_rate
print("Pounds converted into Dollar:",dollars)
# Out:
# Please enter an amount in pounds:£ 100
# Pounds converted into Dollar: 127.0
