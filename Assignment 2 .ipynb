# %%
#list
# 1)Create a list of 5 random numbers and print the list.
num_list = [1,6,7,9,10]
print(num_list)

# %%
#2. Insert 3 new values to the list and print the updated list.
num_list= num_list +[12,14,16]
print('Updated list:',num_list)
# Out:
# Updated list: [1, 6, 7, 9, 10, 12, 14, 16]

# %%
# 3. Try to use a for loop to print each element in the list. 
for i in num_list:
   print('Elements in The List is:',i)
# Out:
# Elements in The List is: 1
# Elements in The List is: 6
# Elements in The List is: 7
# Elements in The List is: 9
# Elements in The List is: 10
# Elements in The List is: 12
# Elements in The List is: 14
# Elements in The List is: 16

# %%
#Dictionary 
# 1)Create a dictionary with keys 'name', 'age', and 'address' and values 'John', 25, and 'New York' respectively. 
Details={"Name":"John","Age":25,"Address":"New York"}

# %%
# 2)Add a new key-value pair to the dictionary created in Q1 with key 'phone' and value '1234567890'. 
Details['phone'] = 1234567890
print(Details)
# Out:
# {'Name': 'John', 'Age': 25, 'Address': 'New York', 'phone': 1234567890}

# %%
# set
# 1).Create a set with values 1, 2, 3, 4, and 5. 
value_set = {1,2,3,4,5}

# %%
#2)Add the value 6 to the set created in Q1.
value_set.add(6)

# %%
# 3)Remove the value 3 from the set created in Q1. 
value_set.remove(3)

# %%
# Tuple
# 1)Create a tuple with values 1, 2, 3, and 4.
tuple_value = (1,2,3,4)

# %%
#Q2. Print the length of the tuple created in Q1
